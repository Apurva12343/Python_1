# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop('PassengerId',axis=1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1    female  38.0      1      0          PC 17599  71.2833   C85        C
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3    female  35.0      1      0            113803  53.1000  C123        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
df.drop(0,axis=0)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# 5        0            330877   8.4583   NaN        Q
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [890 rows x 12 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.drop(0,axis=0,inplace=True)

# %%
df.set_index("Name",inplace=True)

# %%
df.reset_index("Name",inplace=True)

# %%
df
# Out:
#                                                   Name  PassengerId  Survived  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 1                               Heikkinen, Miss. Laina            3         1
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 3                             Allen, Mr. William Henry            5         0
# 4                                     Moran, Mr. James            6         0
# ..                                                 ...          ...       ...
# 885                              Montvila, Rev. Juozas          887         0
# 886                       Graham, Miss. Margaret Edith          888         1
# 887           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 888                              Behr, Mr. Karl Howell          890         1
# 889                                Dooley, Mr. Patrick          891         0
#
#      Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         1  female  38.0      1      0          PC 17599  71.2833   C85
# 1         3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 2         1  female  35.0      1      0            113803  53.1000  C123
# 3         3    male  35.0      0      0            373450   8.0500   NaN
# 4         3    male   NaN      0      0            330877   8.4583   NaN
# ..      ...     ...   ...    ...    ...               ...      ...   ...
# 885       2    male  27.0      0      0            211536  13.0000   NaN
# 886       1  female  19.0      0      0            112053  30.0000   B42
# 887       3  female   NaN      1      2        W./C. 6607  23.4500   NaN
# 888       1    male  26.0      0      0            111369  30.0000  C148
# 889       3    male  32.0      0      0            370376   7.7500   NaN
#
#     Embarked
# 0          C
# 1          S
# 2          S
# 3          S
# 4          Q
# ..       ...
# 885        S
# 886        S
# 887        S
# 888        C
# 889        Q
#
# [890 rows x 12 columns]

# %%
d = {

    "key1" : [1,2,3,4,5],
    "key2" : [5,6,7,8,9],
    "key3" : [22,33,44,55,77]

}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     5    22
# 1     2     6    33
# 2     3     7    44
# 3     4     8    55
# 4     5     9    77

# %%
df1 = pd.read_csv("taxonomy.csv (1).xls")

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna()
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1.dropna(axis=1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df2 = pd.read_csv("taxonomy.csv (1).xls")

# %%
df2.fillna("Apurva")
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency    Apurva                Apurva
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df
# Out:
#                                                   Name  PassengerId  Survived  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 1                               Heikkinen, Miss. Laina            3         1
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 3                             Allen, Mr. William Henry            5         0
# 4                                     Moran, Mr. James            6         0
# ..                                                 ...          ...       ...
# 885                              Montvila, Rev. Juozas          887         0
# 886                       Graham, Miss. Margaret Edith          888         1
# 887           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 888                              Behr, Mr. Karl Howell          890         1
# 889                                Dooley, Mr. Patrick          891         0
#
#      Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         1  female  38.0      1      0          PC 17599  71.2833   C85
# 1         3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 2         1  female  35.0      1      0            113803  53.1000  C123
# 3         3    male  35.0      0      0            373450   8.0500   NaN
# 4         3    male   NaN      0      0            330877   8.4583   NaN
# ..      ...     ...   ...    ...    ...               ...      ...   ...
# 885       2    male  27.0      0      0            211536  13.0000   NaN
# 886       1  female  19.0      0      0            112053  30.0000   B42
# 887       3  female   NaN      1      2        W./C. 6607  23.4500   NaN
# 888       1    male  26.0      0      0            111369  30.0000  C148
# 889       3    male  32.0      0      0            370376   7.7500   NaN
#
#     Embarked
# 0          C
# 1          S
# 2          S
# 3          S
# 4          Q
# ..       ...
# 885        S
# 886        S
# 887        S
# 888        C
# 889        Q
#
# [890 rows x 12 columns]

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#      index                                               Name  PassengerId  \
# 0        0  Cumings, Mrs. John Bradley (Florence Briggs Th...            2
# 1        1                             Heikkinen, Miss. Laina            3
# 2        2       Futrelle, Mrs. Jacques Heath (Lily May Peel)            4
# 3        3                           Allen, Mr. William Henry            5
# 4        4                                   Moran, Mr. James            6
# ..     ...                                                ...          ...
# 885    885                              Montvila, Rev. Juozas          887
# 886    886                       Graham, Miss. Margaret Edith          888
# 887    887           Johnston, Miss. Catherine Helen "Carrie"          889
# 888    888                              Behr, Mr. Karl Howell          890
# 889    889                                Dooley, Mr. Patrick          891
#
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           1       1  female  38.0      1      0          PC 17599  71.2833
# 1           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 2           1       1  female  35.0      1      0            113803  53.1000
# 3           0       3    male  35.0      0      0            373450   8.0500
# 4           0       3    male   NaN      0      0            330877   8.4583
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 885         0       2    male  27.0      0      0            211536  13.0000
# 886         1       1  female  19.0      0      0            112053  30.0000
# 887         0       3  female   NaN      1      2        W./C. 6607  23.4500
# 888         1       1    male  26.0      0      0            111369  30.0000
# 889         0       3    male  32.0      0      0            370376   7.7500
#
#     Cabin Embarked
# 0     C85        C
# 1     NaN        S
# 2    C123        S
# 3     NaN        S
# 4     NaN        Q
# ..    ...      ...
# 885   NaN        S
# 886   B42        S
# 887   NaN        S
# 888  C148        C
# 889   NaN        Q
#
# [890 rows x 13 columns]

# %%
g = df.groupby('Survived')

# %%
g.sum('Fare')
# Out:
#            index  PassengerId  Pclass       Age  SibSp  Parch        Fare
# Survived
# 0         244315       245411    1387  12963.50    303    181  12135.4699
# 1         151290       151974     667   8219.67    162    159  16551.2294

# %%
g.mean('Fare')
# Out:
#                index  PassengerId    Pclass        Age     SibSp     Parch  \
# Survived
# 0         445.830292   447.830292  2.531022  30.646572  0.552920  0.330292
# 1         442.368421   444.368421  1.950292  28.343690  0.473684  0.464912
#
#                Fare
# Survived
# 0         22.145018
# 1         48.395408

# %%
g1 = df.groupby('Pclass')

# %%
g1.sum('Fare')
# Out:
#          index  PassengerId  Survived      Age  SibSp  Parch        Fare
# Pclass
# 1        99273        99705       136  7111.42     90     77  18177.4125
# 2        81688        82056        87  5168.83     74     70   3801.8417
# 3       214644       215624       119  8902.92    301    193   6707.4451

# %%
g1.mean('Fare')
# Out:
#              index  PassengerId  Survived        Age     SibSp     Parch  \
# Pclass
# 1       459.597222   461.597222  0.629630  38.233441  0.416667  0.356481
# 2       443.956522   445.956522  0.472826  29.877630  0.402174  0.380435
# 3       438.048980   440.048980  0.242857  25.149492  0.614286  0.393878
#
#              Fare
# Pclass
# 1       84.154687
# 2       20.662183
# 3       13.688663

# %%
g1.max('Fare')
# Out:
#         index  PassengerId  Survived   Age  SibSp  Parch      Fare
# Pclass
# 1         888          890         1  80.0      3      4  512.3292
# 2         885          887         1  70.0      3      3   73.5000
# 3         889          891         1  74.0      8      6   69.5500

# %%
g1.max('Fare').transpose()
# Out:
# Pclass              1      2       3
# index        888.0000  885.0  889.00
# PassengerId  890.0000  887.0  891.00
# Survived       1.0000    1.0    1.00
# Age           80.0000   70.0   74.00
# SibSp          3.0000    3.0    8.00
# Parch          4.0000    3.0    6.00
# Fare         512.3292   73.5   69.55

# %%
df
# Out:
#      index                                               Name  PassengerId  \
# 0        0  Cumings, Mrs. John Bradley (Florence Briggs Th...            2
# 1        1                             Heikkinen, Miss. Laina            3
# 2        2       Futrelle, Mrs. Jacques Heath (Lily May Peel)            4
# 3        3                           Allen, Mr. William Henry            5
# 4        4                                   Moran, Mr. James            6
# ..     ...                                                ...          ...
# 885    885                              Montvila, Rev. Juozas          887
# 886    886                       Graham, Miss. Margaret Edith          888
# 887    887           Johnston, Miss. Catherine Helen "Carrie"          889
# 888    888                              Behr, Mr. Karl Howell          890
# 889    889                                Dooley, Mr. Patrick          891
#
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           1       1  female  38.0      1      0          PC 17599  71.2833
# 1           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 2           1       1  female  35.0      1      0            113803  53.1000
# 3           0       3    male  35.0      0      0            373450   8.0500
# 4           0       3    male   NaN      0      0            330877   8.4583
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 885         0       2    male  27.0      0      0            211536  13.0000
# 886         1       1  female  19.0      0      0            112053  30.0000
# 887         0       3  female   NaN      1      2        W./C. 6607  23.4500
# 888         1       1    male  26.0      0      0            111369  30.0000
# 889         0       3    male  32.0      0      0            370376   7.7500
#
#     Cabin Embarked
# 0     C85        C
# 1     NaN        S
# 2    C123        S
# 3     NaN        S
# 4     NaN        Q
# ..    ...      ...
# 885   NaN        S
# 886   B42        S
# 887   NaN        S
# 888  C148        C
# 889   NaN        Q
#
# [890 rows x 13 columns]

# %%
df5 = df[['Name','Survived','Pclass']][0:5]

# %%
df6 = df[['Name','Survived','Pclass']][5:10]

# %%
df5
# Out:
#                                                 Name  Survived  Pclass
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 1                             Heikkinen, Miss. Laina         1       3
# 2       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3

# %%
df6
# Out:
#                                                 Name  Survived  Pclass
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
pd.concat([df5,df6])
# Out:
#                                                 Name  Survived  Pclass
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 1                             Heikkinen, Miss. Laina         1       3
# 2       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 3                           Allen, Mr. William Henry         0       3
# 4                                   Moran, Mr. James         0       3
# 5                            McCarthy, Mr. Timothy J         0       1
# 6                     Palsson, Master. Gosta Leonard         0       3
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 8                Nasser, Mrs. Nicholas (Adele Achem)         1       2
# 9                    Sandstrom, Miss. Marguerite Rut         1       3

# %%
pd.concat([df5,df6],axis=1)
# Out:
#                                                 Name  Survived  Pclass  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...       1.0     1.0
# 1                             Heikkinen, Miss. Laina       1.0     3.0
# 2       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1.0     1.0
# 3                           Allen, Mr. William Henry       0.0     3.0
# 4                                   Moran, Mr. James       0.0     3.0
# 5                                                NaN       NaN     NaN
# 6                                                NaN       NaN     NaN
# 7                                                NaN       NaN     NaN
# 8                                                NaN       NaN     NaN
# 9                                                NaN       NaN     NaN
#
#                                                 Name  Survived  Pclass
# 0                                                NaN       NaN     NaN
# 1                                                NaN       NaN     NaN
# 2                                                NaN       NaN     NaN
# 3                                                NaN       NaN     NaN
# 4                                                NaN       NaN     NaN
# 5                            McCarthy, Mr. Timothy J       0.0     1.0
# 6                     Palsson, Master. Gosta Leonard       0.0     3.0
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)       1.0     3.0
# 8                Nasser, Mrs. Nicholas (Adele Achem)       1.0     2.0
# 9                    Sandstrom, Miss. Marguerite Rut       1.0     3.0

# %%
df7 = pd.concat([df5,df6],axis=1)

# %%
df7.fillna('Apurva')
# Out:
#                                                 Name Survived  Pclass  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...      1.0     1.0
# 1                             Heikkinen, Miss. Laina      1.0     3.0
# 2       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1.0     1.0
# 3                           Allen, Mr. William Henry      0.0     3.0
# 4                                   Moran, Mr. James      0.0     3.0
# 5                                             Apurva   Apurva  Apurva
# 6                                             Apurva   Apurva  Apurva
# 7                                             Apurva   Apurva  Apurva
# 8                                             Apurva   Apurva  Apurva
# 9                                             Apurva   Apurva  Apurva
#
#                                                 Name Survived  Pclass
# 0                                             Apurva   Apurva  Apurva
# 1                                             Apurva   Apurva  Apurva
# 2                                             Apurva   Apurva  Apurva
# 3                                             Apurva   Apurva  Apurva
# 4                                             Apurva   Apurva  Apurva
# 5                            McCarthy, Mr. Timothy J      0.0     1.0
# 6                     Palsson, Master. Gosta Leonard      0.0     3.0
# 7  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      1.0     3.0
# 8                Nasser, Mrs. Nicholas (Adele Achem)      1.0     2.0
# 9                    Sandstrom, Miss. Marguerite Rut      1.0     3.0

# %%
data1 = pd.DataFrame({
    'key1':[1,2,3,4,5],
    'key2':[6,7,8,9,0],
    'key3':[1,3,4,6,7]
})

# %%
data2 = pd.DataFrame({
    'key1':[1,2,3,45,5],
    'key4':[66,7,8,9,0],
    'key5':[1,3,44,6,7]
})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     6     1
# 1     2     7     3
# 2     3     8     4
# 3     4     9     6
# 4     5     0     7

# %%
data2
# Out:
#    key1  key4  key5
# 0     1    66     1
# 1     2     7     3
# 2     3     8    44
# 3    45     9     6
# 4     5     0     7

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     6     1    66     1
# 1     2     7     3     7     3
# 2     3     8     4     8    44
# 3     5     0     7     0     7

# %%
pd.merge(data1,data2,how='right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   6.0   1.0    66     1
# 1     2   7.0   3.0     7     3
# 2     3   8.0   4.0     8    44
# 3    45   NaN   NaN     9     6
# 4     5   0.0   7.0     0     7

# %%
pd.merge(data1,data2,how='left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     6     1  66.0   1.0
# 1     2     7     3   7.0   3.0
# 2     3     8     4   8.0  44.0
# 3     4     9     6   NaN   NaN
# 4     5     0     7   0.0   7.0

# %%
pd.merge(data1,data2,how='outer')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   6.0   1.0  66.0   1.0
# 1     2   7.0   3.0   7.0   3.0
# 2     3   8.0   4.0   8.0  44.0
# 3     4   9.0   6.0   NaN   NaN
# 4     5   0.0   7.0   0.0   7.0
# 5    45   NaN   NaN   9.0   6.0

# %%
pd.merge(data1,data2,how='cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     6     1       1    66     1
# 1        1     6     1       2     7     3
# 2        1     6     1       3     8    44
# 3        1     6     1      45     9     6
# 4        1     6     1       5     0     7
# 5        2     7     3       1    66     1
# 6        2     7     3       2     7     3
# 7        2     7     3       3     8    44
# 8        2     7     3      45     9     6
# 9        2     7     3       5     0     7
# 10       3     8     4       1    66     1
# 11       3     8     4       2     7     3
# 12       3     8     4       3     8    44
# 13       3     8     4      45     9     6
# 14       3     8     4       5     0     7
# 15       4     9     6       1    66     1
# 16       4     9     6       2     7     3
# 17       4     9     6       3     8    44
# 18       4     9     6      45     9     6
# 19       4     9     6       5     0     7
# 20       5     0     7       1    66     1
# 21       5     0     7       2     7     3
# 22       5     0     7       3     8    44
# 23       5     0     7      45     9     6
# 24       5     0     7       5     0     7

# %%
data1 = pd.DataFrame({
    'key1':[1,2,3,4,5],
    'key2':[6,7,8,9,0],
    'key3':[1,3,4,6,7]
},index=['a','b','c','d','e'])

# %%
data2 = pd.DataFrame({
    'key4':[1,2,3,45,5],
    'key5':[66,7,8,9,0],
    'key6':[1,3,44,6,7]
},index=['a','b','h','i','j'])

# %%
data1
# Out:
#    key1  key2  key3
# a     1     6     1
# b     2     7     3
# c     3     8     4
# d     4     9     6
# e     5     0     7

# %%
data2
# Out:
#    key4  key5  key6
# a     1    66     1
# b     2     7     3
# h     3     8    44
# i    45     9     6
# j     5     0     7

# %%
data1.join(data2)
# Out:
#    key1  key2  key3  key4  key5  key6
# a     1     6     1   1.0  66.0   1.0
# b     2     7     3   2.0   7.0   3.0
# c     3     8     4   NaN   NaN   NaN
# d     4     9     6   NaN   NaN   NaN
# e     5     0     7   NaN   NaN   NaN

# %%
data1.join(data2,how='inner')
# Out:
#    key1  key2  key3  key4  key5  key6
# a     1     6     1     1    66     1
# b     2     7     3     2     7     3

# %%
data1.join(data2,how='left')
# Out:
#    key1  key2  key3  key4  key5  key6
# a     1     6     1   1.0  66.0   1.0
# b     2     7     3   2.0   7.0   3.0
# c     3     8     4   NaN   NaN   NaN
# d     4     9     6   NaN   NaN   NaN
# e     5     0     7   NaN   NaN   NaN

# %%
data1.join(data2,how='outer')
# Out:
#    key1  key2  key3  key4  key5  key6
# a   1.0   6.0   1.0   1.0  66.0   1.0
# b   2.0   7.0   3.0   2.0   7.0   3.0
# c   3.0   8.0   4.0   NaN   NaN   NaN
# d   4.0   9.0   6.0   NaN   NaN   NaN
# e   5.0   0.0   7.0   NaN   NaN   NaN
# h   NaN   NaN   NaN   3.0   8.0  44.0
# i   NaN   NaN   NaN  45.0   9.0   6.0
# j   NaN   NaN   NaN   5.0   0.0   7.0

# %%
data1.join(data2,how='right')
# Out:
#    key1  key2  key3  key4  key5  key6
# a   1.0   6.0   1.0     1    66     1
# b   2.0   7.0   3.0     2     7     3
# h   NaN   NaN   NaN     3     8    44
# i   NaN   NaN   NaN    45     9     6
# j   NaN   NaN   NaN     5     0     7

# %%
data1.join(data2,how='left')
# Out:
#    key1  key2  key3  key4  key5  key6
# a     1     6     1   1.0  66.0   1.0
# b     2     7     3   2.0   7.0   3.0
# c     3     8     4   NaN   NaN   NaN
# d     4     9     6   NaN   NaN   NaN
# e     5     0     7   NaN   NaN   NaN

# %%
df
# Out:
#      index                                               Name  PassengerId  \
# 0        0  Cumings, Mrs. John Bradley (Florence Briggs Th...            2
# 1        1                             Heikkinen, Miss. Laina            3
# 2        2       Futrelle, Mrs. Jacques Heath (Lily May Peel)            4
# 3        3                           Allen, Mr. William Henry            5
# 4        4                                   Moran, Mr. James            6
# ..     ...                                                ...          ...
# 885    885                              Montvila, Rev. Juozas          887
# 886    886                       Graham, Miss. Margaret Edith          888
# 887    887           Johnston, Miss. Catherine Helen "Carrie"          889
# 888    888                              Behr, Mr. Karl Howell          890
# 889    889                                Dooley, Mr. Patrick          891
#
#      Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0           1       1  female  38.0      1      0          PC 17599  71.2833
# 1           1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 2           1       1  female  35.0      1      0            113803  53.1000
# 3           0       3    male  35.0      0      0            373450   8.0500
# 4           0       3    male   NaN      0      0            330877   8.4583
# ..        ...     ...     ...   ...    ...    ...               ...      ...
# 885         0       2    male  27.0      0      0            211536  13.0000
# 886         1       1  female  19.0      0      0            112053  30.0000
# 887         0       3  female   NaN      1      2        W./C. 6607  23.4500
# 888         1       1    male  26.0      0      0            111369  30.0000
# 889         0       3    male  32.0      0      0            370376   7.7500
#
#     Cabin Embarked
# 0     C85        C
# 1     NaN        S
# 2    C123        S
# 3     NaN        S
# 4     NaN        Q
# ..    ...      ...
# 885   NaN        S
# 886   B42        S
# 887   NaN        S
# 888  C148        C
# 889   NaN        Q
#
# [890 rows x 13 columns]

# %%
df.drop(['index'],axis=1,inplace=True)

# %%
df
# Out:
#                                                   Name  PassengerId  Survived  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 1                               Heikkinen, Miss. Laina            3         1
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 3                             Allen, Mr. William Henry            5         0
# 4                                     Moran, Mr. James            6         0
# ..                                                 ...          ...       ...
# 885                              Montvila, Rev. Juozas          887         0
# 886                       Graham, Miss. Margaret Edith          888         1
# 887           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 888                              Behr, Mr. Karl Howell          890         1
# 889                                Dooley, Mr. Patrick          891         0
#
#      Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         1  female  38.0      1      0          PC 17599  71.2833   C85
# 1         3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 2         1  female  35.0      1      0            113803  53.1000  C123
# 3         3    male  35.0      0      0            373450   8.0500   NaN
# 4         3    male   NaN      0      0            330877   8.4583   NaN
# ..      ...     ...   ...    ...    ...               ...      ...   ...
# 885       2    male  27.0      0      0            211536  13.0000   NaN
# 886       1  female  19.0      0      0            112053  30.0000   B42
# 887       3  female   NaN      1      2        W./C. 6607  23.4500   NaN
# 888       1    male  26.0      0      0            111369  30.0000  C148
# 889       3    male  32.0      0      0            370376   7.7500   NaN
#
#     Embarked
# 0          C
# 1          S
# 2          S
# 3          S
# 4          Q
# ..       ...
# 885        S
# 886        S
# 887        S
# 888        C
# 889        Q
#
# [890 rows x 12 columns]

# %%
df['Fare_INR'] = df['Fare'].apply(lambda x : x*85.41)

# %%
df
# Out:
#                                                   Name  PassengerId  Survived  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 1                               Heikkinen, Miss. Laina            3         1
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 3                             Allen, Mr. William Henry            5         0
# 4                                     Moran, Mr. James            6         0
# ..                                                 ...          ...       ...
# 885                              Montvila, Rev. Juozas          887         0
# 886                       Graham, Miss. Margaret Edith          888         1
# 887           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 888                              Behr, Mr. Karl Howell          890         1
# 889                                Dooley, Mr. Patrick          891         0
#
#      Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         1  female  38.0      1      0          PC 17599  71.2833   C85
# 1         3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 2         1  female  35.0      1      0            113803  53.1000  C123
# 3         3    male  35.0      0      0            373450   8.0500   NaN
# 4         3    male   NaN      0      0            330877   8.4583   NaN
# ..      ...     ...   ...    ...    ...               ...      ...   ...
# 885       2    male  27.0      0      0            211536  13.0000   NaN
# 886       1  female  19.0      0      0            112053  30.0000   B42
# 887       3  female   NaN      1      2        W./C. 6607  23.4500   NaN
# 888       1    male  26.0      0      0            111369  30.0000  C148
# 889       3    male  32.0      0      0            370376   7.7500   NaN
#
#     Embarked     Fare_INR
# 0          C  6088.306653
# 1          S   676.874250
# 2          S  4535.271000
# 3          S   687.550500
# 4          Q   722.423403
# ..       ...          ...
# 885        S  1110.330000
# 886        S  2562.300000
# 887        S  2002.864500
# 888        C  2562.300000
# 889        Q   661.927500
#
# [890 rows x 13 columns]

# %%
df['Fare_INR']
# Out:
# 0      6088.306653
# 1       676.874250
# 2      4535.271000
# 3       687.550500
# 4       722.423403
#           ...
# 885    1110.330000
# 886    2562.300000
# 887    2002.864500
# 888    2562.300000
# 889     661.927500
# Name: Fare_INR, Length: 890, dtype: float64

# %%
df.head()
# Out:
#                                                 Name  PassengerId  Survived  \
# 0  Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 1                             Heikkinen, Miss. Laina            3         1
# 2       Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 3                           Allen, Mr. William Henry            5         0
# 4                                   Moran, Mr. James            6         0
#
#    Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0       1  female  38.0      1      0          PC 17599  71.2833   C85
# 1       3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 2       1  female  35.0      1      0            113803  53.1000  C123
# 3       3    male  35.0      0      0            373450   8.0500   NaN
# 4       3    male   NaN      0      0            330877   8.4583   NaN
#
#   Embarked     Fare_INR
# 0        C  6088.306653
# 1        S   676.874250
# 2        S  4535.271000
# 3        S   687.550500
# 4        Q   722.423403

# %%
df['Name_len'] = df['Name'].apply(len)

# %%
df
# Out:
#                                                   Name  PassengerId  Survived  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 1                               Heikkinen, Miss. Laina            3         1
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 3                             Allen, Mr. William Henry            5         0
# 4                                     Moran, Mr. James            6         0
# ..                                                 ...          ...       ...
# 885                              Montvila, Rev. Juozas          887         0
# 886                       Graham, Miss. Margaret Edith          888         1
# 887           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 888                              Behr, Mr. Karl Howell          890         1
# 889                                Dooley, Mr. Patrick          891         0
#
#      Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         1  female  38.0      1      0          PC 17599  71.2833   C85
# 1         3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 2         1  female  35.0      1      0            113803  53.1000  C123
# 3         3    male  35.0      0      0            373450   8.0500   NaN
# 4         3    male   NaN      0      0            330877   8.4583   NaN
# ..      ...     ...   ...    ...    ...               ...      ...   ...
# 885       2    male  27.0      0      0            211536  13.0000   NaN
# 886       1  female  19.0      0      0            112053  30.0000   B42
# 887       3  female   NaN      1      2        W./C. 6607  23.4500   NaN
# 888       1    male  26.0      0      0            111369  30.0000  C148
# 889       3    male  32.0      0      0            370376   7.7500   NaN
#
#     Embarked     Fare_INR  Name_len
# 0          C  6088.306653        51
# 1          S   676.874250        22
# 2          S  4535.271000        44
# 3          S   687.550500        24
# 4          Q   722.423403        16
# ..       ...          ...       ...
# 885        S  1110.330000        21
# 886        S  2562.300000        28
# 887        S  2002.864500        40
# 888        C  2562.300000        21
# 889        Q   661.927500        19
#
# [890 rows x 14 columns]

# %%
def Fare_class(x):
    if x <=10:
        return 'Cheap Pricce'
    elif x>10 and x <=20:
       return "Mid Price"
    else:
        return "High Price"

# %%
df['Class_Price'] = df['Fare'].apply(Fare_class)

# %%
df
# Out:
#                                                   Name  PassengerId  Survived  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 1                               Heikkinen, Miss. Laina            3         1
# 2         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 3                             Allen, Mr. William Henry            5         0
# 4                                     Moran, Mr. James            6         0
# ..                                                 ...          ...       ...
# 885                              Montvila, Rev. Juozas          887         0
# 886                       Graham, Miss. Margaret Edith          888         1
# 887           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 888                              Behr, Mr. Karl Howell          890         1
# 889                                Dooley, Mr. Patrick          891         0
#
#      Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0         1  female  38.0      1      0          PC 17599  71.2833   C85
# 1         3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 2         1  female  35.0      1      0            113803  53.1000  C123
# 3         3    male  35.0      0      0            373450   8.0500   NaN
# 4         3    male   NaN      0      0            330877   8.4583   NaN
# ..      ...     ...   ...    ...    ...               ...      ...   ...
# 885       2    male  27.0      0      0            211536  13.0000   NaN
# 886       1  female  19.0      0      0            112053  30.0000   B42
# 887       3  female   NaN      1      2        W./C. 6607  23.4500   NaN
# 888       1    male  26.0      0      0            111369  30.0000  C148
# 889       3    male  32.0      0      0            370376   7.7500   NaN
#
#     Embarked     Fare_INR  Name_len   Class_Price
# 0          C  6088.306653        51    High Price
# 1          S   676.874250        22  Cheap Pricce
# 2          S  4535.271000        44    High Price
# 3          S   687.550500        24  Cheap Pricce
# 4          Q   722.423403        16  Cheap Pricce
# ..       ...          ...       ...           ...
# 885        S  1110.330000        21     Mid Price
# 886        S  2562.300000        28    High Price
# 887        S  2002.864500        40    High Price
# 888        C  2562.300000        21    High Price
# 889        Q   661.927500        19  Cheap Pricce
#
# [890 rows x 15 columns]
