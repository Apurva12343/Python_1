# %%
#Algerian Forest Fires Dataset Project EDA

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Algerian_forest_fires_dataset_UPDATE.csv",header=1)

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %%
"""3. Data Checks to perform
Check Missing values
Check Duplicates
Check data type
Check the number of unique values of each column
Check statistics of data set
Check various categories present in the different categorical column"""
# Out:
# '3. Data Checks to perform\nCheck Missing values\nCheck Duplicates\nCheck data type\nCheck the number of unique values of each column\nCheck statistics of data set\nCheck various categories present in the different categorical column'

# %%
#Check Missing value

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %% [markdown]
# there is 2 dataset in this file 2 nd dataset starts from 122 row

# %%
#Add new column with region

# %%
#Divided into two region by adding a region colimn as there was two dataset 
df.loc[:122,'Region'] = 1
df.loc[122:,'Region'] = 2
df['Region'] = df['Region'].astype(int)

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# Region         0
# dtype: int64

# %%
#Removing Null values
df = df.dropna().reset_index(drop=True)

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
#Removing String Column 
df.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes    Region
# 122  FWI  Classes         2

# %%
df = df.drop(122).reset_index(drop=True)

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 238  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 239  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 240  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 241  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 242  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 0    0.5   not fire          1
# ...

# %%
#as we can see there are some unwanted spaces in colummns name we can fix that
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
# As we can see every data type is object so we have to change data type for all columns except Classes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    object
#  4   RH           243 non-null    object
#  5   Ws           243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 28.6+ KB

# %%
objects = [i for i in df.columns if df[i].dtypes=='O']

# %%
for i in objects:
    if i != 'Classes':
        df[i] = df[i].astype(float)

# %%
# changed Datatyes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    float64
#  1   month        243 non-null    float64
#  2   year         243 non-null    float64
#  3   Temperature  243 non-null    float64
#  4   RH           243 non-null    float64
#  5   Ws           243 non-null    float64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: float64(13), int64(1), object(1)
# memory usage: 28.6+ KB

# %%
# Check Duplicates
df.duplicated().sum()
# There Are no Duplicates
# Out:
# np.int64(0)

# %%
# Unique Values per column
df.nunique()
# Out:
# day             31
# month            4
# year             1
# Temperature     19
# RH              62
# Ws              18
# Rain            39
# FFMC           173
# DMC            165
# DC             197
# ISI            106
# BUI            173
# FWI            125
# Classes          8
# Region           2
# dtype: int64

# %%
#Check statistics of data set
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# ...

# %%
df.describe().T
# Out:
#              count         mean        std     min      25%     50%      75%  \
# day          243.0    15.761317   8.842552     1.0     8.00    16.0    23.00
# month        243.0     7.502058   1.114793     6.0     7.00     8.0     8.00
# year         243.0  2012.000000   0.000000  2012.0  2012.00  2012.0  2012.00
# Temperature  243.0    32.152263   3.628039    22.0    30.00    32.0    35.00
# RH           243.0    62.041152  14.828160    21.0    52.50    63.0    73.50
# Ws           243.0    15.493827   2.811385     6.0    14.00    15.0    17.00
# Rain         243.0     0.762963   2.003207     0.0     0.00     0.0     0.50
# FFMC         243.0    77.842387  14.349641    28.6    71.85    83.3    88.30
# DMC          243.0    14.680658  12.393040     0.7     5.80    11.3    20.80
# DC           243.0    49.430864  47.665606     6.9    12.35    33.1    69.10
# ISI          243.0     4.742387   4.154234     0.0     1.40     3.5     7.25
# ...

# %%
# Check Unique value of target variables
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.Classes.value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
# As we can see above that tere are many unwanted spaces in classes column
df.Classes = df.Classes.str.strip()

# %%
df.Classes.value_counts()
# Out:
# Classes
# fire        137
# not fire    106
# Name: count, dtype: int64

# %%
#Region1
#Bejaia Region
df[:122]
# Out:
#       day  month    year  Temperature    RH    Ws  Rain  FFMC  DMC    DC  ISI  \
# 0     1.0    6.0  2012.0         29.0  57.0  18.0   0.0  65.7  3.4   7.6  1.3
# 1     2.0    6.0  2012.0         29.0  61.0  13.0   1.3  64.4  4.1   7.6  1.0
# 2     3.0    6.0  2012.0         26.0  82.0  22.0  13.1  47.1  2.5   7.1  0.3
# 3     4.0    6.0  2012.0         25.0  89.0  13.0   2.5  28.6  1.3   6.9  0.0
# 4     5.0    6.0  2012.0         27.0  77.0  16.0   0.0  64.8  3.0  14.2  1.2
# ..    ...    ...     ...          ...   ...   ...   ...   ...  ...   ...  ...
# 117  26.0    9.0  2012.0         31.0  54.0  11.0   0.0  82.0  6.0  16.3  2.5
# 118  27.0    9.0  2012.0         31.0  66.0  11.0   0.0  85.7  8.3  24.9  4.0
# 119  28.0    9.0  2012.0         32.0  47.0  14.0   0.7  77.5  7.1   8.8  1.8
# 120  29.0    9.0  2012.0         26.0  80.0  16.0   1.8  47.4  2.9   7.7  0.3
# 121  30.0    9.0  2012.0         25.0  78.0  14.0   1.4  45.0  1.9   7.5  0.2
#
#      BUI  FWI   Classes  Region
# ...

# %%
#Region2 
#Sidi-Bel abbes region
df[122:]
# Out:
#       day  month    year  Temperature    RH    Ws  Rain  FFMC   DMC    DC  \
# 122   1.0    6.0  2012.0         32.0  71.0  12.0   0.7  57.1   2.5   8.2
# 123   2.0    6.0  2012.0         30.0  73.0  13.0   4.0  55.7   2.7   7.8
# 124   3.0    6.0  2012.0         29.0  80.0  14.0   2.0  48.7   2.2   7.6
# 125   4.0    6.0  2012.0         30.0  64.0  14.0   0.0  79.4   5.2  15.4
# 126   5.0    6.0  2012.0         32.0  60.0  14.0   0.2  77.1   6.0  17.6
# ..    ...    ...     ...          ...   ...   ...   ...   ...   ...   ...
# 238  26.0    9.0  2012.0         30.0  65.0  14.0   0.0  85.4  16.0  44.5
# 239  27.0    9.0  2012.0         28.0  87.0  15.0   4.4  41.1   6.5   8.0
# 240  28.0    9.0  2012.0         27.0  87.0  29.0   0.5  45.9   3.5   7.9
# 241  29.0    9.0  2012.0         24.0  54.0  18.0   0.1  79.7   4.3  15.2
# 242  30.0    9.0  2012.0         24.0  64.0  15.0   0.2  67.3   3.8  16.5
#
#      ISI   BUI  FWI   Classes  Region
# 122  0.6   2.8  0.2  not fire       2
# ...

# %%
df.to_csv('Cleaned_Algerian_Fire.csv',index=False)

# %% [markdown]
# ##Exploratory Data Analysis(EDA)

# %%
#Chart 1
fig,axis = plt.subplots(1,3,figsize=(15,8))
plt.subplot(131)
sns.histplot(data=df,x='Rain',y = 'Temperature',bins=10,kde=True,hue='Classes')
plt.subplot(132)
sns.histplot(data=df,x='Region',y = 'Rain',bins=10 ,hue='Classes')
plt.subplot(133)
sns.histplot(data=df,x='Region',y = 'Temperature',bins=10 ,hue='Classes')
# Out:
# <Axes: xlabel='Region', ylabel='Temperature'>

# %%
df1 = df[['Temperature', 'RH', 'Ws', 'Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region']]

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df1.corr(numeric_only=True),annot=True)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Chart 2
fig,axis = plt.subplots(1,3,figsize=(15,8))
plt.subplot(131)
sns.barplot(data=df,x='month',y = 'Rain',hue='Classes')
plt.subplot(132)
sns.barplot(data=df,x='month',y = 'Temperature',hue='Classes')
plt.subplot(133)
sns.histplot(data=df,x='Region',y = 'month',hue='Classes')
# Out:
# <Axes: xlabel='Region', ylabel='month'>

# %%
dftemp= df.loc[df['Region']== 2]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data= df,ec = 'black', palette= 'Set2')
plt.title('Fire Analysis Month wise for Sidi-Bel Abbes Region', fontsize=18, weight='bold')
plt.ylabel('Count', weight = 'bold')
plt.xlabel('Months', weight= 'bold')
plt.legend(loc='upper right')
plt.xticks(np.arange(4), ['June','July', 'August', 'September',])
plt.grid(alpha = 0.5,axis = 'y')
plt.show()

# %%
dftemp= df.loc[df['Region']== 1]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data= df,ec = 'black', palette= 'Set2')
plt.title('Fire Analysis Month wise for Bejaia Region', fontsize=18, weight='bold')
plt.ylabel('Count', weight = 'bold')
plt.xlabel('Months', weight= 'bold')
plt.legend(loc='upper right')
plt.xticks(np.arange(4), ['June','July', 'August', 'September',])
plt.grid(alpha = 0.5,axis = 'y')
plt.show()

# %%
#Boxplot
ax = sns.boxplot(df['FWI'], color= 'red')

# %%
for feature in df1:
    sns.histplot(data = df1,x=feature, hue = 'Classes')
    plt.legend(labels=['Fire','Not Fire'])
    plt.title(feature)
    plt.show()

# %% [markdown]
# #Report:
# 1: As we Can See on Chart 1
# (A): There Is more fire where rain mm is 0 and No fire Where Rain mm more than 0.(Fig 1)
# (B):The Chances of fire rises when temperature goes above 35. and below 35 there is negligible chances of fire.(fig 1)
# (C):Region 2 has more chances of fire as compared to region 1. (fig 2)
# (D): there is less rain on region 2 as comapared to region . (Fig 2)
# (E):Region 2 Temprature is higher as compared to region 1. we can say thats because region 2 has higher Chances of fire.
